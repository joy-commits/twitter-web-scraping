# %%
#installing tweepy

#pip install tweepy

#pip install git+https://github.com/tweepy/tweepy.git

# %%
#importing tweepy and dependencies

import tweepy
from tweepy import OAuthHandler
from timeit import default_timer as timer

# %%
#filling in the authorization credentials

consumer_key = 'DUGBUUEWPPysg8UX1P67kZgju'
consumer_secret = 'rzpMjD3sEIdNpMMYKTNMsunjWe2Q2H6ijYxr48c4R0nt5ZCxbT'
access_token = '1207019641014562823-XVijoKX9ue7uWa58gRcSdrYUqovZC7'
access_secret = '5h3etW1bm8RZHt1zpAtDSmufTuKPKeTSmZD1XDkzUwDtr'

# %%
#authorizing the keys and tokens

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

# %%
#passing authorization details to tweepy

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
#using the "search_tweets" method of the API class in Tweepy to extract the hashtag

hashtag = "#100daysofcode"
tweets = api.search_tweets(q=hashtag, count=100)

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @SwissCognitive: #DataScience and #DataAnalytics 🧑‍💻
#
# via Data Works
#
# #Algorithm #Analysis #BigData #Technology #Coding #DataAnalysis #A…
# RT @AI_Advice: TOP 18 #DataScience Podcasts v/@DataScienceDojo!
#
# #5G #100DaysOfCode #ai #analytics #artificialintelligence #bi #bigdata #bi…
# RT @FatimaYousufi: Day 1 of #100DaysOfCode
# Implementing a simple web page using html and css
# #Web3 #web3community #Website #webdevelopment…
# RT @FatimaYousufi: Day 1 of #100DaysOfCode
# Implementing a simple web page using html and css
# #Web3 #web3community #Website #webdevelopment…
# Day 1 of #100DaysOfCode
# Implementing a simple web page using html and css
# #Web3 #web3community #Website… https://t.co/dYvclmIR8Y
# RT @Lupova_Maria: Day 8 of #100DaysOfCode
# Pandas Course from Kaggle
# #Python #datamanipulation https://t.co/6yRwMLQAP3
# RT @MajAnony1: #Java #100DaysOfCode #javaquiz #javaprogramming #programming #CPP #fun_java
#
# Recalling Java interview questions......
#
# A…
# ...

# %%
#saving in the CSV format

import csv

with open('tweets.csv', 'w', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['id', 'created_at', 'text'])
    
    for tweet in tweets:
        writer.writerow([tweet.id, tweet.created_at, tweet.text])

# %%
#reading the CSV data

import pandas as pd
df = pd.read_csv("tweets.csv")
df
# Out:
#                      id                 created_at  \
# 0   1620177772244074500  2023-01-30 21:50:57+00:00
# 1   1620177771304550401  2023-01-30 21:50:56+00:00
# 2   1620177738702229504  2023-01-30 21:50:49+00:00
# 3   1620177721614823424  2023-01-30 21:50:44+00:00
# 4   1620177608225996803  2023-01-30 21:50:17+00:00
# ..                  ...                        ...
# 93  1620173345844248580  2023-01-30 21:33:21+00:00
# 94  1620173325078233089  2023-01-30 21:33:16+00:00
# 95  1620173315913687046  2023-01-30 21:33:14+00:00
# 96  1620173246934179842  2023-01-30 21:32:58+00:00
# 97  1620173227124486146  2023-01-30 21:32:53+00:00
#
#                                                  text
# 0   RT @SwissCognitive: #DataScience and #DataAnal...
# 1   RT @AI_Advice: TOP 18 #DataScience Podcasts v/...
# 2   RT @FatimaYousufi: Day 1 of #100DaysOfCode \r\...
# 3   RT @FatimaYousufi: Day 1 of #100DaysOfCode \r\...
# 4   Day 1 of #100DaysOfCode \r\nImplementing a sim...
# ...
